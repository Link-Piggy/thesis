# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import seaborn as sns
import math
import os
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix

from tensorflow.keras.layers import RepeatVector, Dense, Activation, Input, LSTM, GRU, Bidirectional, Concatenate, Dot
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K

# %% [markdown]
# ### Build the basic LSTM model

# %%
def base_model(Tx, n_x, n_a): 
    # Define the input layer and specify the shape
    input = Input(shape=(Tx, n_x))
    
    # build LSTM frame with the time_step = Tx
    all_state = LSTM(n_a, return_sequences=True)(input)

    # Create empty list to append the outputs while you iterate
    outputs = []
    
    # Loop over tx
    for t in range(Tx):
        # Apply densor to the hidden state output of LSTM_Cell
        out = Dense(1, activation='sigmoid')(all_state[:, t, :])
        # add the output to "outputs"
        outputs.append(out)
        
    # Create model instance
    model = Model(inputs=input, outputs=outputs)
    
    return model

# %% [markdown]
# ### Build the deep Bi-LSTM model

# %%
def deep_bi_lstm_model(Tx, n_x, n_a):   
    # Define the input layer and specify the shape
    input = Input(shape=(Tx, n_x))
    
    # build LSTM frame with the time_step = Tx
    x = Bidirectional(LSTM(n_a, return_sequences=True))(input)
    all_state = Bidirectional(LSTM(n_a, return_sequences=True))(x)

    # Create empty list to append the outputs while you iterate
    outputs = []
    
    # Loop over tx
    for t in range(Tx):
        # Apply densor to the hidden state output of LSTM_Cell
        out = Dense(1, activation='sigmoid')(all_state[:, t, :])
        # add the output to "outputs"
        outputs.append(out)
        
    # Create model instance
    model = Model(inputs=input, outputs=outputs)
    
    return model

# %% [markdown]
# ### Build the attention_based model

# %%
def softmax(x, axis=1):
    ndim = K.ndim(x)
    if ndim == 2:
        return K.softmax(x)
    elif ndim > 2:
        e = K.exp(x - K.max(x, axis=axis, keepdims=True))
        s = K.sum(e, axis=axis, keepdims=True)
        return e / s
    else:
        raise ValueError('Cannot apply softmax to a tensor that is 1D')

def one_step_attention(a, s_prev):
    # Use repeator to repeat s_prev to be of shape (m, Tx, n_s) so that you can concatenate it with all hidden states "a" 
    s_prev = RepeatVector(Tx)(s_prev)
    # Use concatenator to concatenate a and s_prev on the last axis 
    # For grading purposes, please list 'a' first and 's_prev' second, in this order.
    concat = Concatenate(axis=-1)([a, s_prev])
    # Use densor1 to propagate concat through a small fully-connected neural network to compute the "intermediate energies" variable e. 
    e = Dense(8, activation = "tanh")(concat)
    # Use densor2 to propagate e through a small fully-connected neural network to compute the "energies" variable energies. 
    energies = Dense(1, activation = "relu")(e)
    # Use "activator" on "energies" to compute the attention weights "alphas" 
    alphas = Activation(softmax)(energies)
    # Use dotor together with "alphas" and "a", in this order, to compute the context vector to be given to the next (post-attention) LSTM-cell
    context = Dot(axes = 1)([alphas,a])
    
    return context


def attention_model(Tx, n_a, n_s, n_x):
    # Define the inputs of your model with a shape (Tx,)
    # Define s0 (initial hidden state) and c0 (initial cell state) for the decoder LSTM with shape (n_s,)
    X = Input(shape=(Tx, n_x))
    s0 = Input(shape=(n_s,), name='s0')
    c0 = Input(shape=(n_s,), name='c0')
    s = s0
    c = c0
    
    # Initialize empty list of outputs
    outputs = []
    
    # Step 1: Define the encoder with Bi-LSTM. 
    a = Bidirectional(LSTM(units=n_a, return_sequences=True))(X)
    
    # Step 2: Define decoder iterating for Tx steps
    for t in range(Tx):
    
        # Step 2.A: Perform one step of the attention mechanism to get back the context vector at step t 
        context = one_step_attention(a, s)
        
        # Step 2.B: Apply the post-attention LSTM cell to the "context" vector.
        s, _, c = LSTM(n_s, return_state = True)(inputs=context, initial_state=[s, c])
        
        # Step 2.C: Apply Dense layer to the hidden state output of the post-attention LSTM 
        out = Dense(1, activation='sigmoid')(s)
        
        # Step 2.D: Append "out" to the "outputs" list 
        outputs.append(out)
    
    # Step 3: Create model instance taking three inputs and returning the list of outputs. 
    model = Model(inputs=[X,s0,c0], outputs=outputs)
    
    return model

# %% [markdown]
# ### Build the evaluation and plot functions

# %%
def plot(LSTM_history):
    plt.figure(figsize=(12, 7))
    plt.title('Model Cross Entropy Loss')
    plt.plot(LSTM_history.history['loss'], label='train')
    plt.plot(LSTM_history.history['val_loss'], label='validation')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
def multi_evaluation(X_test_1, X_test_2, test_df_1, test_df_2):
    pred_1 = LSTM_model.predict(X_test_1)
    pred_1 = np.array(pred_1).flatten('F').round()
    pred_2 = LSTM_model.predict(X_test_2)
    pred_2 = np.array(pred_2).flatten('F').round()
    pred = np.concatenate((pred_1.reshape(-1,1), pred_2.reshape(-1,1)), axis=1)

    y_true_1 = test_df_1.iloc[:,-1].to_numpy(dtype=int)
    y_true_2 = test_df_2.iloc[:,-1].to_numpy(dtype=int)
    y_true = np.concatenate((y_true_1.reshape(-1,1), y_true_2.reshape(-1,1)), axis=1)

    accuracy = round(accuracy_score(y_true, pred), ndigits=4)
    F1_score = round(f1_score(y_true, pred, average='weighted'), ndigits=4)
    print('Accuracy on test dataset is:', accuracy)
    print('F1-score on test dataset is:', F1_score)

    T = (y_true==1).sum()
    c = 0
    for i in range(y_true.shape[0]):
        if y_true[i][0]==0 and y_true[i][1]==0:
            c+=pred[i][0]
            c+=pred[i][1]
    FA = round(c/T, ndigits=4)
    print('FA is:',FA)

    c = 0
    for j in range(y_true.shape[0]):
        if (y_true[j][0]+y_true[j][1]-pred[j][0]-pred[j][1])>0:
            c+=(y_true[j][0]+y_true[j][1]-pred[j][0]-pred[j][1])
    MISS = round(c/T, ndigits=4)
    print('MISS is:',MISS)

    DER = FA + MISS
    print('DER is:', DER)

    return accuracy, F1_score, FA, MISS, DER

def single_acc(LSTM_history):
    acc = [LSTM_history.history[i] for i in LSTM_history.history if i.endswith('accuracy') and i.startswith('val')]
    single_accuracy = round(np.array(acc).mean(axis=0).max(), ndigits=4)
    print('The average accuracy on validation dataset is:', single_accuracy)
    return single_accuracy

def plot_confusion_matrix(X_test, test_df):
    pred = LSTM_model.predict(X_test)
    pred = np.array(pred).flatten('F').round()
    y_true = test_df.iloc[:,-1].to_numpy(dtype=int)
    out = confusion_matrix(y_true, pred)

    group_counts = ["{0:0.0f}".format(value) for value in out.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in out.flatten()/np.sum(out)]
    box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
    box_labels = np.asarray(box_labels).reshape(2,2)

    plt.figure(figsize = (6,5))
    sns.heatmap(out,xticklabels=['Not signing','Signing'], yticklabels=['Not signing','Signing'],
            cmap="YlGnBu", fmt="", annot=box_labels)
    plt.xlabel('Predicted Classes')
    plt.ylabel('True Classes')
    plt.show()

# %% [markdown]
# ### Read and split data

# %%
def between_signer_split(path_to_df, test_file_name, Tx):
    assert test_file_name in ['PiKe', 'KN', 'ReKe', 'SuJu'], 'Wrong test_file_name'

    file_paths = [os.path.join(path_to_df, df_csv) for df_csv in os.listdir(path_to_df)]
    # choose one whole video as test set and set the rest as train set
    test_path = os.path.join(path_to_df, 'df_clean_'+test_file_name+'.csv')
    test_df = pd.read_csv(test_path)
    test_df_1 = test_df.iloc[:int(test_df.shape[0]/2), :]
    test_df_2 = test_df.iloc[int(test_df.shape[0]/2):, :]

    train_df = pd.DataFrame()
    for i in file_paths:
        if test_file_name not in i:
            print(i)
            train_df = pd.concat([train_df, pd.read_csv(i)], ignore_index = True)

    # crop the train_df and test_df in order to covert       
    if train_df.shape[0]%Tx*-1 != 0:
        train_df = train_df.iloc[:train_df.shape[0]%Tx*-1,:]
    if test_df.shape[0]%Tx*-1 != 0:
        test_df = test_df.iloc[:test_df.shape[0]%Tx*-1,:]
    if test_df_1.shape[0]%Tx*-1 != 0:
        test_df_1 = test_df_1.iloc[:test_df_1.shape[0]%Tx*-1,:]
        test_df_2 = test_df_2.iloc[:test_df_2.shape[0]%Tx*-1,:]
    return train_df, test_df, test_df_1, test_df_2


Tx = 60
path_to_df = '/content/drive/MyDrive/thesis/clean_df_F/'
test_file_name = 'PiKe'

train_df, test_df, test_df_1, test_df_2 = between_signer_split(path_to_df, test_file_name, Tx)
n_x = train_df.shape[1]-1

X_train = train_df.iloc[:,:-1].to_numpy().reshape((-1, Tx, n_x))
y_train = train_df.iloc[:,-1].to_numpy(dtype='float32').reshape((Tx, -1, 1),order='f')

X_test = test_df.iloc[:,:-1].to_numpy().reshape((-1, Tx, n_x))
y_test = test_df.iloc[:,-1].to_numpy(dtype='float32').reshape((Tx, -1, 1),order='f')

X_test_1 = test_df_1.iloc[:,:-1].to_numpy().reshape((-1, Tx, n_x))
y_test_1 = test_df_1.iloc[:,-1].to_numpy(dtype='float32').reshape((Tx, -1, 1),order='f')

X_test_2 = test_df_2.iloc[:,:-1].to_numpy().reshape((-1, Tx, n_x))
y_test_2 = test_df_2.iloc[:,-1].to_numpy(dtype='float32').reshape((Tx, -1, 1),order='f')

print('X_train shape :', X_train.shape)
print('X_test shape :', X_test.shape)
print('X_test_1 shape :', X_test_1.shape)
print('X_test_2 shape :', X_test_2.shape)
# Out:
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_KN.csv
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_ReKe.csv
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_SuJu.csv
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_SuJu_F.csv
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_ReKe_F.csv
# /content/drive/MyDrive/thesis/clean_df_F/df_clean_KN_F.csv
# X_train shape : (6473, 60, 24)
# X_test shape : (880, 60, 24)
# X_test_1 shape : (440, 60, 24)
# X_test_2 shape : (440, 60, 24)

# %% [markdown]
# ### Train the basic LSTM and deep Bi-LSTM model

# %%
n_a = 16
LSTM_model = deep_bi_lstm_model(Tx, n_x, n_a)
# LSTM_model = base_model(Tx, n_x, n_a)

LSTM_model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=8, verbose=0, mode='min', restore_best_weights=True)
LSTM_history = LSTM_model.fit(X_train, list(y_train), epochs=50, batch_size=64, verbose=0, 
                              validation_data=(X_test,list(y_test)), callbacks=[early_stopping])

# single evaluation
single_acc(LSTM_history)
multi_evaluation(X_test_1, X_test_2, test_df_1, test_df_2)
plot(LSTM_history)
plot_confusion_matrix(X_test, test_df)
# Out:
# The average accuracy on validation dataset is: 0.8141
# 14/14 [==============================] - 2s 16ms/step
# 14/14 [==============================] - 0s 17ms/step
# Accuracy on test dataset is: 0.6412
# F1-score on test dataset is: 0.7841
# FA is: 0.1717
# MISS is: 0.1854
# DER is: 0.3571
# 28/28 [==============================] - 0s 17ms/step

# %% [markdown]
# ### Build the attention-based model

# %%
n_a = 32
n_s = 16
m = X_train.shape[0]
s0 = np.zeros((m, n_s))
c0 = np.zeros((m, n_s))

m_val = X_test.shape[0]
s0_val = np.zeros((m_val, n_s))
c0_val = np.zeros((m_val, n_s))

LSTM_model = attention_model(Tx, n_a, n_s, n_x)
LSTM_model.compile(optimizer=Adam(learning_rate=0.003), loss='binary_crossentropy', metrics=['accuracy'])
early_stopping = EarlyStopping(monitor='val_loss', patience=8, verbose=0, mode='min', restore_best_weights=True)
LSTM_history = LSTM_model.fit([X_train, s0, c0], list(y_train), epochs=50, batch_size=64, 
                              validation_data=([X_test, s0_val, c0_val],list(y_test)), callbacks=[early_stopping])

# multi evaluation
m_test = X_test_1.shape[0]
s0_test = np.zeros((m_test, n_s))
c0_test = np.zeros((m_test, n_s))

single_acc(LSTM_history)
multi_evaluation([X_test_1, s0_test, c0_test], [X_test_2, s0_test, c0_test], test_df_1, test_df_2)
plot(LSTM_history)
plot_confusion_matrix([X_test, s0_val, c0_val], test_df)
# Out:
# Epoch 1/50
# 105/105 [==============================] - 272s 720ms/step - loss: 33.3107 - dense_1094_loss: 0.5723 - dense_1097_loss: 0.5692 - dense_1100_loss: 0.5666 - dense_1103_loss: 0.5585 - dense_1106_loss: 0.5512 - dense_1109_loss: 0.5566 - dense_1112_loss: 0.5572 - dense_1115_loss: 0.5520 - dense_1118_loss: 0.5481 - dense_1121_loss: 0.5466 - dense_1124_loss: 0.5473 - dense_1127_loss: 0.5441 - dense_1130_loss: 0.5459 - dense_1133_loss: 0.5463 - dense_1136_loss: 0.5529 - dense_1139_loss: 0.5485 - dense_1142_loss: 0.5449 - dense_1145_loss: 0.5452 - dense_1148_loss: 0.5442 - dense_1151_loss: 0.5446 - dense_1154_loss: 0.5455 - dense_1157_loss: 0.5485 - dense_1160_loss: 0.5462 - dense_1163_loss: 0.5429 - dense_1166_loss: 0.5414 - dense_1169_loss: 0.5559 - dense_1172_loss: 0.5512 - dense_1175_loss: 0.5470 - dense_1178_loss: 0.5430 - dense_1181_loss: 0.5429 - dense_1184_loss: 0.5487 - dense_1187_loss: 0.5448 - dense_1190_loss: 0.5494 - dense_1193_loss: 0.5490 - dense_1196_loss: 0.5485 - dense_1199_loss: 0.5538 - dense_1202_loss: 0.5614 - dense_1205_loss: 0.5523 - dense_1208_loss: 0.5538 - dense_1211_loss: 0.5566 - dense_1214_loss: 0.5515 - dense_1217_loss: 0.5546 - dense_1220_loss: 0.5592 - dense_1223_loss: 0.5550 - dense_1226_loss: 0.5568 - dense_1229_loss: 0.5598 - dense_1232_loss: 0.5654 - dense_1235_loss: 0.5562 - dense_1238_loss: 0.5616 - dense_1241_loss: 0.5593 - dense_1244_loss: 0.5601 - dense_1247_loss: 0.5604 - dense_1250_loss: 0.5661 - dense_1253_loss: 0.5679 - dense_1256_loss: 0.5672 - dense_1259_loss: 0.5746 - dense_1262_loss: 0.5773 - dense_1265_loss: 0.5766 - dense_1268_loss: 0.5782 - dense_1271_loss: 0.5777 - dense_1094_accuracy: 0.7053 - dense_1097_accuracy: 0.7041 - dense_1100_accuracy: 0.6997 - dense_1103_accuracy: 0.7116 - dense_1106_accuracy: 0.7173 - dense_1109_accuracy: 0.7180 - dense_1112_accuracy: 0.7099 - dense_1115_accuracy: 0.7165 - dense_1118_accuracy: 0.7197 - dense_1121_accuracy: 0.7192 - dense_1124_accuracy: 0.7209 - dense_1127_accuracy: 0.7188 - dense_1130_accuracy: 0.7170 - dense_1133_accuracy: 0.7165 - dense_1136_accuracy: 0.7126 - dense_1139_accuracy: 0.7179 - dense_1142_accuracy: 0.7161 - dense_1145_accuracy: 0.7170 - dense_1148_accuracy: 0.7155 - dense_1151_accuracy: 0.7153 - dense_1154_accuracy: 0.7176 - dense_1157_accuracy: 0.7197 - dense_1160_accuracy: 0.7212 - dense_1163_accuracy: 0.7222 - dense_1166_accuracy: 0.7231 - dense_1169_accuracy: 0.7063 - dense_1172_accuracy: 0.7144 - dense_1175_accuracy: 0.7188 - dense_1178_accuracy: 0.7179 - dense_1181_accuracy: 0.7177 - dense_1184_accuracy: 0.7140 - dense_1187_accuracy: 0.7236 - dense_1190_accuracy: 0.7164 - dense_1193_accuracy: 0.7138 - dense_1196_accuracy: 0.7180 - dense_1199_accuracy: 0.7093 - dense_1202_accuracy: 0.7054 - dense_1205_accuracy: 0.7195 - dense_1208_accuracy: 0.7158 - dense_1211_accuracy: 0.7150 - dense_1214_accuracy: 0.7171 - dense_1217_accuracy: 0.7117 - dense_1220_accuracy: 0.7077 - dense_1223_accuracy: 0.7123 - dense_1226_accuracy: 0.7155 - dense_1229_accuracy: 0.7126 - dense_1232_accuracy: 0.7033 - dense_1235_accuracy: 0.7144 - dense_1238_accuracy: 0.7107 - dense_1241_accuracy: 0.7105 - dense_1244_accuracy: 0.7164 - dense_1247_accuracy: 0.7084 - dense_1250_accuracy: 0.7047 - dense_1253_accuracy: 0.7026 - dense_1256_accuracy: 0.7054 - dense_1259_accuracy: 0.6947 - dense_1262_accuracy: 0.6956 - dense_1265_accuracy: 0.6997 - dense_1268_accuracy: 0.6983 - dense_1271_accuracy: 0.6976 - val_loss: 41.0348 - val_dense_1094_loss: 0.7181 - val_dense_1097_loss: 0.7025 - val_dense_1100_loss: 0.6709 - val_dense_1103_loss: 0.6321 - val_dense_1106_loss: 0.6720 - val_dense_1109_loss: 0.6781 - val_dense_1112_loss: 0.6757 - val_dense_1115_loss: 0.6930 - val_dense_1118_loss: 0.6658 - val_dense_1121_loss: 0.6828 - val_dense_1124_loss: 0.6908 - val_dense_1127_loss: 0.6713 - val_dense_1130_loss: 0.6722 - val_dense_1133_loss: 0.6843 - val_dense_1136_loss: 0.6769 - val_dense_1139_loss: 0.6805 - val_dense_1142_loss: 0.6926 - val_dense_1145_loss: 0.6954 - val ...
# Epoch 2/50
# 105/105 [==============================] - 39s 375ms/step - loss: 27.6358 - dense_1094_loss: 0.4818 - dense_1097_loss: 0.4750 - dense_1100_loss: 0.4705 - dense_1103_loss: 0.4668 - dense_1106_loss: 0.4687 - dense_1109_loss: 0.4641 - dense_1112_loss: 0.4643 - dense_1115_loss: 0.4600 - dense_1118_loss: 0.4593 - dense_1121_loss: 0.4587 - dense_1124_loss: 0.4575 - dense_1127_loss: 0.4596 - dense_1130_loss: 0.4604 - dense_1133_loss: 0.4595 - dense_1136_loss: 0.4602 - dense_1139_loss: 0.4605 - dense_1142_loss: 0.4599 - dense_1145_loss: 0.4589 - dense_1148_loss: 0.4583 - dense_1151_loss: 0.4537 - dense_1154_loss: 0.4551 - dense_1157_loss: 0.4555 - dense_1160_loss: 0.4542 - dense_1163_loss: 0.4550 - dense_1166_loss: 0.4540 - dense_1169_loss: 0.4547 - dense_1172_loss: 0.4575 - dense_1175_loss: 0.4576 - dense_1178_loss: 0.4573 - dense_1181_loss: 0.4575 - dense_1184_loss: 0.4564 - dense_1187_loss: 0.4527 - dense_1190_loss: 0.4549 - dense_1193_loss: 0.4538 - dense_1196_loss: 0.4531 - dense_1199_loss: 0.4572 - dense_1202_loss: 0.4570 - dense_1205_loss: 0.4580 - dense_1208_loss: 0.4599 - dense_1211_loss: 0.4592 - dense_1214_loss: 0.4571 - dense_1217_loss: 0.4573 - dense_1220_loss: 0.4574 - dense_1223_loss: 0.4587 - dense_1226_loss: 0.4579 - dense_1229_loss: 0.4603 - dense_1232_loss: 0.4615 - dense_1235_loss: 0.4557 - dense_1238_loss: 0.4607 - dense_1241_loss: 0.4584 - dense_1244_loss: 0.4588 - dense_1247_loss: 0.4595 - dense_1250_loss: 0.4631 - dense_1253_loss: 0.4653 - dense_1256_loss: 0.4594 - dense_1259_loss: 0.4677 - dense_1262_loss: 0.4743 - dense_1265_loss: 0.4720 - dense_1268_loss: 0.4750 - dense_1271_loss: 0.4775 - dense_1094_accuracy: 0.7680 - dense_1097_accuracy: 0.7722 - dense_1100_accuracy: 0.7755 - dense_1103_accuracy: 0.7752 - dense_1106_accuracy: 0.7746 - dense_1109_accuracy: 0.7809 - dense_1112_accuracy: 0.7799 - dense_1115_accuracy: 0.7845 - dense_1118_accuracy: 0.7838 - dense_1121_accuracy: 0.7839 - dense_1124_accuracy: 0.7851 - dense_1127_accuracy: 0.7839 - dense_1130_accuracy: 0.7826 - dense_1133_accuracy: 0.7844 - dense_1136_accuracy: 0.7826 - dense_1139_accuracy: 0.7809 - dense_1142_accuracy: 0.7847 - dense_1145_accuracy: 0.7839 - dense_1148_accuracy: 0.7823 - dense_1151_accuracy: 0.7881 - dense_1154_accuracy: 0.7857 - dense_1157_accuracy: 0.7865 - dense_1160_accuracy: 0.7877 - dense_1163_accuracy: 0.7872 - dense_1166_accuracy: 0.7854 - dense_1169_accuracy: 0.7886 - dense_1172_accuracy: 0.7854 - dense_1175_accuracy: 0.7844 - dense_1178_accuracy: 0.7844 - dense_1181_accuracy: 0.7877 - dense_1184_accuracy: 0.7863 - dense_1187_accuracy: 0.7872 - dense_1190_accuracy: 0.7872 - dense_1193_accuracy: 0.7877 - dense_1196_accuracy: 0.7886 - dense_1199_accuracy: 0.7883 - dense_1202_accuracy: 0.7865 - dense_1205_accuracy: 0.7835 - dense_1208_accuracy: 0.7827 - dense_1211_accuracy: 0.7844 - dense_1214_accuracy: 0.7856 - dense_1217_accuracy: 0.7851 - dense_1220_accuracy: 0.7863 - dense_1223_accuracy: 0.7862 - dense_1226_accuracy: 0.7869 - dense_1229_accuracy: 0.7871 - dense_1232_accuracy: 0.7878 - dense_1235_accuracy: 0.7907 - dense_1238_accuracy: 0.7890 - dense_1241_accuracy: 0.7931 - dense_1244_accuracy: 0.7914 - dense_1247_accuracy: 0.7931 - dense_1250_accuracy: 0.7883 - dense_1253_accuracy: 0.7883 - dense_1256_accuracy: 0.7904 - dense_1259_accuracy: 0.7827 - dense_1262_accuracy: 0.7827 - dense_1265_accuracy: 0.7818 - dense_1268_accuracy: 0.7793 - dense_1271_accuracy: 0.7764 - val_loss: 44.6910 - val_dense_1094_loss: 0.8107 - val_dense_1097_loss: 0.7346 - val_dense_1100_loss: 0.7495 - val_dense_1103_loss: 0.7072 - val_dense_1106_loss: 0.6830 - val_dense_1109_loss: 0.6910 - val_dense_1112_loss: 0.6940 - val_dense_1115_loss: 0.7231 - val_dense_1118_loss: 0.7168 - val_dense_1121_loss: 0.7210 - val_dense_1124_loss: 0.7347 - val_dense_1127_loss: 0.7133 - val_dense_1130_loss: 0.7132 - val_dense_1133_loss: 0.6775 - val_dense_1136_loss: 0.7025 - val_dense_1139_loss: 0.7059 - val_dense_1142_loss: 0.7102 - val_dense_1145_loss: 0.7023 - val_ ...
# Epoch 3/50
# 105/105 [==============================] - 40s 384ms/step - loss: 26.2942 - dense_1094_loss: 0.4462 - dense_1097_loss: 0.4417 - dense_1100_loss: 0.4361 - dense_1103_loss: 0.4306 - dense_1106_loss: 0.4333 - dense_1109_loss: 0.4312 - dense_1112_loss: 0.4327 - dense_1115_loss: 0.4293 - dense_1118_loss: 0.4295 - dense_1121_loss: 0.4315 - dense_1124_loss: 0.4319 - dense_1127_loss: 0.4344 - dense_1130_loss: 0.4352 - dense_1133_loss: 0.4350 - dense_1136_loss: 0.4363 - dense_1139_loss: 0.4427 - dense_1142_loss: 0.4427 - dense_1145_loss: 0.4403 - dense_1148_loss: 0.4411 - dense_1151_loss: 0.4386 - dense_1154_loss: 0.4416 - dense_1157_loss: 0.4409 - dense_1160_loss: 0.4386 - dense_1163_loss: 0.4397 - dense_1166_loss: 0.4388 - dense_1169_loss: 0.4380 - dense_1172_loss: 0.4439 - dense_1175_loss: 0.4424 - dense_1178_loss: 0.4432 - dense_1181_loss: 0.4401 - dense_1184_loss: 0.4360 - dense_1187_loss: 0.4341 - dense_1190_loss: 0.4352 - dense_1193_loss: 0.4333 - dense_1196_loss: 0.4335 - dense_1199_loss: 0.4352 - dense_1202_loss: 0.4339 - dense_1205_loss: 0.4358 - dense_1208_loss: 0.4381 - dense_1211_loss: 0.4396 - dense_1214_loss: 0.4385 - dense_1217_loss: 0.4351 - dense_1220_loss: 0.4377 - dense_1223_loss: 0.4392 - dense_1226_loss: 0.4394 - dense_1229_loss: 0.4403 - dense_1232_loss: 0.4392 - dense_1235_loss: 0.4367 - dense_1238_loss: 0.4404 - dense_1241_loss: 0.4377 - dense_1244_loss: 0.4387 - dense_1247_loss: 0.4367 - dense_1250_loss: 0.4391 - dense_1253_loss: 0.4394 - dense_1256_loss: 0.4359 - dense_1259_loss: 0.4413 - dense_1262_loss: 0.4468 - dense_1265_loss: 0.4463 - dense_1268_loss: 0.4501 - dense_1271_loss: 0.4536 - dense_1094_accuracy: 0.7938 - dense_1097_accuracy: 0.7980 - dense_1100_accuracy: 0.7980 - dense_1103_accuracy: 0.8030 - dense_1106_accuracy: 0.7997 - dense_1109_accuracy: 0.8030 - dense_1112_accuracy: 0.8035 - dense_1115_accuracy: 0.8053 - dense_1118_accuracy: 0.8032 - dense_1121_accuracy: 0.8000 - dense_1124_accuracy: 0.8008 - dense_1127_accuracy: 0.8009 - dense_1130_accuracy: 0.8000 - dense_1133_accuracy: 0.8021 - dense_1136_accuracy: 0.8009 - dense_1139_accuracy: 0.7986 - dense_1142_accuracy: 0.7973 - dense_1145_accuracy: 0.7988 - dense_1148_accuracy: 0.7989 - dense_1151_accuracy: 0.7998 - dense_1154_accuracy: 0.7985 - dense_1157_accuracy: 0.7992 - dense_1160_accuracy: 0.7991 - dense_1163_accuracy: 0.7992 - dense_1166_accuracy: 0.8008 - dense_1169_accuracy: 0.7982 - dense_1172_accuracy: 0.7980 - dense_1175_accuracy: 0.7983 - dense_1178_accuracy: 0.7953 - dense_1181_accuracy: 0.7995 - dense_1184_accuracy: 0.8003 - dense_1187_accuracy: 0.8000 - dense_1190_accuracy: 0.7989 - dense_1193_accuracy: 0.8009 - dense_1196_accuracy: 0.8032 - dense_1199_accuracy: 0.8029 - dense_1202_accuracy: 0.8009 - dense_1205_accuracy: 0.7977 - dense_1208_accuracy: 0.7926 - dense_1211_accuracy: 0.7962 - dense_1214_accuracy: 0.7962 - dense_1217_accuracy: 0.7962 - dense_1220_accuracy: 0.7953 - dense_1223_accuracy: 0.7995 - dense_1226_accuracy: 0.7982 - dense_1229_accuracy: 0.8009 - dense_1232_accuracy: 0.7979 - dense_1235_accuracy: 0.8017 - dense_1238_accuracy: 0.8018 - dense_1241_accuracy: 0.8030 - dense_1244_accuracy: 0.8044 - dense_1247_accuracy: 0.8020 - dense_1250_accuracy: 0.8008 - dense_1253_accuracy: 0.8008 - dense_1256_accuracy: 0.8038 - dense_1259_accuracy: 0.8012 - dense_1262_accuracy: 0.7976 - dense_1265_accuracy: 0.8003 - dense_1268_accuracy: 0.7965 - dense_1271_accuracy: 0.7971 - val_loss: 39.3634 - val_dense_1094_loss: 0.6666 - val_dense_1097_loss: 0.6883 - val_dense_1100_loss: 0.6932 - val_dense_1103_loss: 0.6863 - val_dense_1106_loss: 0.6653 - val_dense_1109_loss: 0.6461 - val_dense_1112_loss: 0.6662 - val_dense_1115_loss: 0.6709 - val_dense_1118_loss: 0.6680 - val_dense_1121_loss: 0.6659 - val_dense_1124_loss: 0.6654 - val_dense_1127_loss: 0.6571 - val_dense_1130_loss: 0.6648 - val_dense_1133_loss: 0.6782 - val_dense_1136_loss: 0.6988 - val_dense_1139_loss: 0.6862 - val_dense_1142_loss: 0.7076 - val_dense_1145_loss: 0.6895 - val_ ...
# Epoch 4/50
# 105/105 [==============================] - 40s 385ms/step - loss: 24.6688 - dense_1094_loss: 0.4203 - dense_1097_loss: 0.4148 - dense_1100_loss: 0.4080 - dense_1103_loss: 0.4032 - dense_1106_loss: 0.4024 - dense_1109_loss: 0.4033 - dense_1112_loss: 0.4047 - dense_1115_loss: 0.4014 - dense_1118_loss: 0.4014 - dense_1121_loss: 0.4039 - dense_1124_loss: 0.4034 - dense_1127_loss: 0.4063 - dense_1130_loss: 0.4068 - dense_1133_loss: 0.4081 - dense_1136_loss: 0.4086 - dense_1139_loss: 0.4132 - dense_1142_loss: 0.4135 - dense_1145_loss: 0.4128 - dense_1148_loss: 0.4144 - dense_1151_loss: 0.4118 - dense_1154_loss: 0.4148 - dense_1157_loss: 0.4144 - dense_1160_loss: 0.4132 - dense_1163_loss: 0.4163 - dense_1166_loss: 0.4169 - dense_1169_loss: 0.4143 - dense_1172_loss: 0.4175 - dense_1175_loss: 0.4164 - dense_1178_loss: 0.4171 - dense_1181_loss: 0.4171 - dense_1184_loss: 0.4153 - dense_1187_loss: 0.4135 - dense_1190_loss: 0.4128 - dense_1193_loss: 0.4106 - dense_1196_loss: 0.4094 - dense_1199_loss: 0.4093 - dense_1202_loss: 0.4088 - dense_1205_loss: 0.4085 - dense_1208_loss: 0.4123 - dense_1211_loss: 0.4127 - dense_1214_loss: 0.4112 - dense_1217_loss: 0.4096 - dense_1220_loss: 0.4099 - dense_1223_loss: 0.4092 - dense_1226_loss: 0.4095 - dense_1229_loss: 0.4084 - dense_1232_loss: 0.4086 - dense_1235_loss: 0.4047 - dense_1238_loss: 0.4082 - dense_1241_loss: 0.4092 - dense_1244_loss: 0.4102 - dense_1247_loss: 0.4078 - dense_1250_loss: 0.4103 - dense_1253_loss: 0.4089 - dense_1256_loss: 0.4080 - dense_1259_loss: 0.4138 - dense_1262_loss: 0.4171 - dense_1265_loss: 0.4190 - dense_1268_loss: 0.4227 - dense_1271_loss: 0.4291 - dense_1094_accuracy: 0.8140 - dense_1097_accuracy: 0.8185 - dense_1100_accuracy: 0.8209 - dense_1103_accuracy: 0.8219 - dense_1106_accuracy: 0.8215 - dense_1109_accuracy: 0.8258 - dense_1112_accuracy: 0.8227 - dense_1115_accuracy: 0.8243 - dense_1118_accuracy: 0.8234 - dense_1121_accuracy: 0.8215 - dense_1124_accuracy: 0.8236 - dense_1127_accuracy: 0.8207 - dense_1130_accuracy: 0.8189 - dense_1133_accuracy: 0.8206 - dense_1136_accuracy: 0.8213 - dense_1139_accuracy: 0.8197 - dense_1142_accuracy: 0.8162 - dense_1145_accuracy: 0.8149 - dense_1148_accuracy: 0.8143 - dense_1151_accuracy: 0.8161 - dense_1154_accuracy: 0.8140 - dense_1157_accuracy: 0.8156 - dense_1160_accuracy: 0.8132 - dense_1163_accuracy: 0.8117 - dense_1166_accuracy: 0.8126 - dense_1169_accuracy: 0.8141 - dense_1172_accuracy: 0.8132 - dense_1175_accuracy: 0.8125 - dense_1178_accuracy: 0.8132 - dense_1181_accuracy: 0.8132 - dense_1184_accuracy: 0.8110 - dense_1187_accuracy: 0.8135 - dense_1190_accuracy: 0.8126 - dense_1193_accuracy: 0.8150 - dense_1196_accuracy: 0.8158 - dense_1199_accuracy: 0.8170 - dense_1202_accuracy: 0.8161 - dense_1205_accuracy: 0.8171 - dense_1208_accuracy: 0.8147 - dense_1211_accuracy: 0.8155 - dense_1214_accuracy: 0.8170 - dense_1217_accuracy: 0.8188 - dense_1220_accuracy: 0.8186 - dense_1223_accuracy: 0.8189 - dense_1226_accuracy: 0.8179 - dense_1229_accuracy: 0.8182 - dense_1232_accuracy: 0.8209 - dense_1235_accuracy: 0.8225 - dense_1238_accuracy: 0.8225 - dense_1241_accuracy: 0.8186 - dense_1244_accuracy: 0.8180 - dense_1247_accuracy: 0.8173 - dense_1250_accuracy: 0.8176 - dense_1253_accuracy: 0.8179 - dense_1256_accuracy: 0.8198 - dense_1259_accuracy: 0.8201 - dense_1262_accuracy: 0.8173 - dense_1265_accuracy: 0.8153 - dense_1268_accuracy: 0.8153 - dense_1271_accuracy: 0.8113 - val_loss: 32.7065 - val_dense_1094_loss: 0.5519 - val_dense_1097_loss: 0.5542 - val_dense_1100_loss: 0.5588 - val_dense_1103_loss: 0.5645 - val_dense_1106_loss: 0.5428 - val_dense_1109_loss: 0.5411 - val_dense_1112_loss: 0.5457 - val_dense_1115_loss: 0.5447 - val_dense_1118_loss: 0.5519 - val_dense_1121_loss: 0.5523 - val_dense_1124_loss: 0.5374 - val_dense_1127_loss: 0.5426 - val_dense_1130_loss: 0.5219 - val_dense_1133_loss: 0.5369 - val_dense_1136_loss: 0.5464 - val_dense_1139_loss: 0.5400 - val_dense_1142_loss: 0.5497 - val_dense_1145_loss: 0.5346 - val_ ...
# Epoch 5/50
# 105/105 [==============================] - 39s 374ms/step - loss: 24.5195 - dense_1094_loss: 0.4108 - dense_1097_loss: 0.4054 - dense_1100_loss: 0.4001 - dense_1103_loss: 0.3990 - dense_1106_loss: 0.3990 - dense_1109_loss: 0.4012 - dense_1112_loss: 0.4018 - dense_1115_loss: 0.4006 - dense_1118_loss: 0.3999 - dense_1121_loss: 0.4016 - dense_1124_loss: 0.4009 - dense_1127_loss: 0.4038 - dense_1130_loss: 0.4041 - dense_1133_loss: 0.4043 - dense_1136_loss: 0.4043 - dense_1139_loss: 0.4093 - dense_1142_loss: 0.4099 - dense_1145_loss: 0.4113 - dense_1148_loss: 0.4121 - dense_1151_loss: 0.4101 - dense_1154_loss: 0.4131 - dense_1157_loss: 0.4105 - dense_1160_loss: 0.4094 - dense_1163_loss: 0.4114 - dense_1166_loss: 0.4137 - dense_1169_loss: 0.4115 - dense_1172_loss: 0.4147 - dense_1175_loss: 0.4138 - dense_1178_loss: 0.4153 - dense_1181_loss: 0.4146 - dense_1184_loss: 0.4124 - dense_1187_loss: 0.4110 - dense_1190_loss: 0.4106 - dense_1193_loss: 0.4090 - dense_1196_loss: 0.4077 - dense_1199_loss: 0.4089 - dense_1202_loss: 0.4071 - dense_1205_loss: 0.4078 - dense_1208_loss: 0.4095 - dense_1211_loss: 0.4103 - dense_1214_loss: 0.4076 - dense_1217_loss: 0.4067 - dense_1220_loss: 0.4081 - dense_1223_loss: 0.4070 - dense_1226_loss: 0.4070 - dense_1229_loss: 0.4075 - dense_1232_loss: 0.4069 - dense_1235_loss: 0.4055 - dense_1238_loss: 0.4093 - dense_1241_loss: 0.4095 - dense_1244_loss: 0.4100 - dense_1247_loss: 0.4059 - dense_1250_loss: 0.4080 - dense_1253_loss: 0.4070 - dense_1256_loss: 0.4066 - dense_1259_loss: 0.4133 - dense_1262_loss: 0.4154 - dense_1265_loss: 0.4165 - dense_1268_loss: 0.4213 - dense_1271_loss: 0.4285 - dense_1094_accuracy: 0.8146 - dense_1097_accuracy: 0.8182 - dense_1100_accuracy: 0.8230 - dense_1103_accuracy: 0.8206 - dense_1106_accuracy: 0.8204 - dense_1109_accuracy: 0.8215 - dense_1112_accuracy: 0.8212 - dense_1115_accuracy: 0.8222 - dense_1118_accuracy: 0.8227 - dense_1121_accuracy: 0.8195 - dense_1124_accuracy: 0.8209 - dense_1127_accuracy: 0.8174 - dense_1130_accuracy: 0.8194 - dense_1133_accuracy: 0.8188 - dense_1136_accuracy: 0.8212 - dense_1139_accuracy: 0.8182 - dense_1142_accuracy: 0.8171 - dense_1145_accuracy: 0.8143 - dense_1148_accuracy: 0.8120 - dense_1151_accuracy: 0.8158 - dense_1154_accuracy: 0.8153 - dense_1157_accuracy: 0.8147 - dense_1160_accuracy: 0.8138 - dense_1163_accuracy: 0.8119 - dense_1166_accuracy: 0.8123 - dense_1169_accuracy: 0.8122 - dense_1172_accuracy: 0.8096 - dense_1175_accuracy: 0.8099 - dense_1178_accuracy: 0.8104 - dense_1181_accuracy: 0.8092 - dense_1184_accuracy: 0.8099 - dense_1187_accuracy: 0.8095 - dense_1190_accuracy: 0.8132 - dense_1193_accuracy: 0.8128 - dense_1196_accuracy: 0.8132 - dense_1199_accuracy: 0.8140 - dense_1202_accuracy: 0.8129 - dense_1205_accuracy: 0.8134 - dense_1208_accuracy: 0.8125 - dense_1211_accuracy: 0.8135 - dense_1214_accuracy: 0.8171 - dense_1217_accuracy: 0.8152 - dense_1220_accuracy: 0.8167 - dense_1223_accuracy: 0.8143 - dense_1226_accuracy: 0.8156 - dense_1229_accuracy: 0.8162 - dense_1232_accuracy: 0.8155 - dense_1235_accuracy: 0.8173 - dense_1238_accuracy: 0.8162 - dense_1241_accuracy: 0.8174 - dense_1244_accuracy: 0.8182 - dense_1247_accuracy: 0.8219 - dense_1250_accuracy: 0.8233 - dense_1253_accuracy: 0.8225 - dense_1256_accuracy: 0.8233 - dense_1259_accuracy: 0.8186 - dense_1262_accuracy: 0.8197 - dense_1265_accuracy: 0.8170 - dense_1268_accuracy: 0.8174 - dense_1271_accuracy: 0.8149 - val_loss: 31.3925 - val_dense_1094_loss: 0.5545 - val_dense_1097_loss: 0.5446 - val_dense_1100_loss: 0.5463 - val_dense_1103_loss: 0.5530 - val_dense_1106_loss: 0.5418 - val_dense_1109_loss: 0.5443 - val_dense_1112_loss: 0.5365 - val_dense_1115_loss: 0.5437 - val_dense_1118_loss: 0.5364 - val_dense_1121_loss: 0.5321 - val_dense_1124_loss: 0.5213 - val_dense_1127_loss: 0.5165 - val_dense_1130_loss: 0.5103 - val_dense_1133_loss: 0.5150 - val_dense_1136_loss: 0.5155 - val_dense_1139_loss: 0.5110 - val_dense_1142_loss: 0.5159 - val_dense_1145_loss: 0.4979 - val_ ...
# Epoch 6/50
# 105/105 [==============================] - 40s 378ms/step - loss: 23.8269 - dense_1094_loss: 0.4043 - dense_1097_loss: 0.4006 - dense_1100_loss: 0.3939 - dense_1103_loss: 0.3888 - dense_1106_loss: 0.3895 - dense_1109_loss: 0.3894 - dense_1112_loss: 0.3894 - dense_1115_loss: 0.3882 - dense_1118_loss: 0.3891 - dense_1121_loss: 0.3911 - dense_1124_loss: 0.3910 - dense_1127_loss: 0.3937 - dense_1130_loss: 0.3930 - dense_1133_loss: 0.3924 - dense_1136_loss: 0.3928 - dense_1139_loss: 0.3974 - dense_1142_loss: 0.3967 - dense_1145_loss: 0.3968 - dense_1148_loss: 0.3973 - dense_1151_loss: 0.3956 - dense_1154_loss: 0.3986 - dense_1157_loss: 0.3976 - dense_1160_loss: 0.3962 - dense_1163_loss: 0.3977 - dense_1166_loss: 0.3980 - dense_1169_loss: 0.3959 - dense_1172_loss: 0.3994 - dense_1175_loss: 0.3993 - dense_1178_loss: 0.4000 - dense_1181_loss: 0.4011 - dense_1184_loss: 0.3995 - dense_1187_loss: 0.3992 - dense_1190_loss: 0.3988 - dense_1193_loss: 0.3964 - dense_1196_loss: 0.3952 - dense_1199_loss: 0.3975 - dense_1202_loss: 0.3955 - dense_1205_loss: 0.3944 - dense_1208_loss: 0.3963 - dense_1211_loss: 0.3979 - dense_1214_loss: 0.3975 - dense_1217_loss: 0.3951 - dense_1220_loss: 0.3986 - dense_1223_loss: 0.3984 - dense_1226_loss: 0.3975 - dense_1229_loss: 0.3977 - dense_1232_loss: 0.3984 - dense_1235_loss: 0.3965 - dense_1238_loss: 0.3990 - dense_1241_loss: 0.3989 - dense_1244_loss: 0.3987 - dense_1247_loss: 0.3961 - dense_1250_loss: 0.3986 - dense_1253_loss: 0.3962 - dense_1256_loss: 0.3964 - dense_1259_loss: 0.4018 - dense_1262_loss: 0.4025 - dense_1265_loss: 0.4061 - dense_1268_loss: 0.4109 - dense_1271_loss: 0.4165 - dense_1094_accuracy: 0.8240 - dense_1097_accuracy: 0.8240 - dense_1100_accuracy: 0.8291 - dense_1103_accuracy: 0.8278 - dense_1106_accuracy: 0.8285 - dense_1109_accuracy: 0.8305 - dense_1112_accuracy: 0.8288 - dense_1115_accuracy: 0.8275 - dense_1118_accuracy: 0.8282 - dense_1121_accuracy: 0.8249 - dense_1124_accuracy: 0.8254 - dense_1127_accuracy: 0.8242 - dense_1130_accuracy: 0.8272 - dense_1133_accuracy: 0.8275 - dense_1136_accuracy: 0.8276 - dense_1139_accuracy: 0.8260 - dense_1142_accuracy: 0.8275 - dense_1145_accuracy: 0.8281 - dense_1148_accuracy: 0.8242 - dense_1151_accuracy: 0.8248 - dense_1154_accuracy: 0.8230 - dense_1157_accuracy: 0.8215 - dense_1160_accuracy: 0.8216 - dense_1163_accuracy: 0.8200 - dense_1166_accuracy: 0.8203 - dense_1169_accuracy: 0.8245 - dense_1172_accuracy: 0.8225 - dense_1175_accuracy: 0.8209 - dense_1178_accuracy: 0.8207 - dense_1181_accuracy: 0.8204 - dense_1184_accuracy: 0.8210 - dense_1187_accuracy: 0.8207 - dense_1190_accuracy: 0.8212 - dense_1193_accuracy: 0.8236 - dense_1196_accuracy: 0.8222 - dense_1199_accuracy: 0.8242 - dense_1202_accuracy: 0.8230 - dense_1205_accuracy: 0.8248 - dense_1208_accuracy: 0.8230 - dense_1211_accuracy: 0.8228 - dense_1214_accuracy: 0.8221 - dense_1217_accuracy: 0.8249 - dense_1220_accuracy: 0.8215 - dense_1223_accuracy: 0.8234 - dense_1226_accuracy: 0.8219 - dense_1229_accuracy: 0.8233 - dense_1232_accuracy: 0.8221 - dense_1235_accuracy: 0.8240 - dense_1238_accuracy: 0.8239 - dense_1241_accuracy: 0.8240 - dense_1244_accuracy: 0.8245 - dense_1247_accuracy: 0.8261 - dense_1250_accuracy: 0.8240 - dense_1253_accuracy: 0.8275 - dense_1256_accuracy: 0.8267 - dense_1259_accuracy: 0.8252 - dense_1262_accuracy: 0.8221 - dense_1265_accuracy: 0.8200 - dense_1268_accuracy: 0.8195 - dense_1271_accuracy: 0.8132 - val_loss: 31.2069 - val_dense_1094_loss: 0.5370 - val_dense_1097_loss: 0.5188 - val_dense_1100_loss: 0.5143 - val_dense_1103_loss: 0.5284 - val_dense_1106_loss: 0.5237 - val_dense_1109_loss: 0.5314 - val_dense_1112_loss: 0.5253 - val_dense_1115_loss: 0.5350 - val_dense_1118_loss: 0.5249 - val_dense_1121_loss: 0.5281 - val_dense_1124_loss: 0.5223 - val_dense_1127_loss: 0.5172 - val_dense_1130_loss: 0.5091 - val_dense_1133_loss: 0.5091 - val_dense_1136_loss: 0.5081 - val_dense_1139_loss: 0.5141 - val_dense_1142_loss: 0.5191 - val_dense_1145_loss: 0.5034 - val_ ...
# Epoch 7/50
# 105/105 [==============================] - 39s 373ms/step - loss: 23.6465 - dense_1094_loss: 0.4022 - dense_1097_loss: 0.3970 - dense_1100_loss: 0.3932 - dense_1103_loss: 0.3891 - dense_1106_loss: 0.3889 - dense_1109_loss: 0.3883 - dense_1112_loss: 0.3898 - dense_1115_loss: 0.3873 - dense_1118_loss: 0.3874 - dense_1121_loss: 0.3878 - dense_1124_loss: 0.3861 - dense_1127_loss: 0.3881 - dense_1130_loss: 0.3874 - dense_1133_loss: 0.3872 - dense_1136_loss: 0.3875 - dense_1139_loss: 0.3932 - dense_1142_loss: 0.3935 - dense_1145_loss: 0.3956 - dense_1148_loss: 0.3962 - dense_1151_loss: 0.3955 - dense_1154_loss: 0.3983 - dense_1157_loss: 0.3975 - dense_1160_loss: 0.3947 - dense_1163_loss: 0.3963 - dense_1166_loss: 0.3962 - dense_1169_loss: 0.3949 - dense_1172_loss: 0.3989 - dense_1175_loss: 0.3985 - dense_1178_loss: 0.3991 - dense_1181_loss: 0.3977 - dense_1184_loss: 0.3956 - dense_1187_loss: 0.3971 - dense_1190_loss: 0.3981 - dense_1193_loss: 0.3956 - dense_1196_loss: 0.3940 - dense_1199_loss: 0.3958 - dense_1202_loss: 0.3931 - dense_1205_loss: 0.3929 - dense_1208_loss: 0.3957 - dense_1211_loss: 0.3963 - dense_1214_loss: 0.3945 - dense_1217_loss: 0.3909 - dense_1220_loss: 0.3928 - dense_1223_loss: 0.3930 - dense_1226_loss: 0.3937 - dense_1229_loss: 0.3914 - dense_1232_loss: 0.3918 - dense_1235_loss: 0.3907 - dense_1238_loss: 0.3925 - dense_1241_loss: 0.3936 - dense_1244_loss: 0.3950 - dense_1247_loss: 0.3926 - dense_1250_loss: 0.3949 - dense_1253_loss: 0.3918 - dense_1256_loss: 0.3921 - dense_1259_loss: 0.3988 - dense_1262_loss: 0.3967 - dense_1265_loss: 0.3982 - dense_1268_loss: 0.4038 - dense_1271_loss: 0.4103 - dense_1094_accuracy: 0.8210 - dense_1097_accuracy: 0.8215 - dense_1100_accuracy: 0.8222 - dense_1103_accuracy: 0.8258 - dense_1106_accuracy: 0.8249 - dense_1109_accuracy: 0.8266 - dense_1112_accuracy: 0.8237 - dense_1115_accuracy: 0.8242 - dense_1118_accuracy: 0.8261 - dense_1121_accuracy: 0.8276 - dense_1124_accuracy: 0.8270 - dense_1127_accuracy: 0.8269 - dense_1130_accuracy: 0.8254 - dense_1133_accuracy: 0.8249 - dense_1136_accuracy: 0.8239 - dense_1139_accuracy: 0.8248 - dense_1142_accuracy: 0.8245 - dense_1145_accuracy: 0.8246 - dense_1148_accuracy: 0.8216 - dense_1151_accuracy: 0.8204 - dense_1154_accuracy: 0.8200 - dense_1157_accuracy: 0.8215 - dense_1160_accuracy: 0.8236 - dense_1163_accuracy: 0.8206 - dense_1166_accuracy: 0.8188 - dense_1169_accuracy: 0.8212 - dense_1172_accuracy: 0.8179 - dense_1175_accuracy: 0.8182 - dense_1178_accuracy: 0.8177 - dense_1181_accuracy: 0.8173 - dense_1184_accuracy: 0.8192 - dense_1187_accuracy: 0.8176 - dense_1190_accuracy: 0.8168 - dense_1193_accuracy: 0.8201 - dense_1196_accuracy: 0.8225 - dense_1199_accuracy: 0.8237 - dense_1202_accuracy: 0.8261 - dense_1205_accuracy: 0.8245 - dense_1208_accuracy: 0.8218 - dense_1211_accuracy: 0.8251 - dense_1214_accuracy: 0.8264 - dense_1217_accuracy: 0.8270 - dense_1220_accuracy: 0.8234 - dense_1223_accuracy: 0.8246 - dense_1226_accuracy: 0.8230 - dense_1229_accuracy: 0.8251 - dense_1232_accuracy: 0.8266 - dense_1235_accuracy: 0.8279 - dense_1238_accuracy: 0.8287 - dense_1241_accuracy: 0.8270 - dense_1244_accuracy: 0.8261 - dense_1247_accuracy: 0.8242 - dense_1250_accuracy: 0.8239 - dense_1253_accuracy: 0.8276 - dense_1256_accuracy: 0.8278 - dense_1259_accuracy: 0.8239 - dense_1262_accuracy: 0.8261 - dense_1265_accuracy: 0.8212 - dense_1268_accuracy: 0.8209 - dense_1271_accuracy: 0.8158 - val_loss: 37.3757 - val_dense_1094_loss: 0.6793 - val_dense_1097_loss: 0.6543 - val_dense_1100_loss: 0.7070 - val_dense_1103_loss: 0.7060 - val_dense_1106_loss: 0.7100 - val_dense_1109_loss: 0.6936 - val_dense_1112_loss: 0.6855 - val_dense_1115_loss: 0.6942 - val_dense_1118_loss: 0.6759 - val_dense_1121_loss: 0.6797 - val_dense_1124_loss: 0.6659 - val_dense_1127_loss: 0.6475 - val_dense_1130_loss: 0.6759 - val_dense_1133_loss: 0.6570 - val_dense_1136_loss: 0.6461 - val_dense_1139_loss: 0.6288 - val_dense_1142_loss: 0.6482 - val_dense_1145_loss: 0.6113 - val_ ...
# Epoch 8/50
# 105/105 [==============================] - 39s 374ms/step - loss: 23.4234 - dense_1094_loss: 0.3971 - dense_1097_loss: 0.3924 - dense_1100_loss: 0.3856 - dense_1103_loss: 0.3829 - dense_1106_loss: 0.3846 - dense_1109_loss: 0.3842 - dense_1112_loss: 0.3867 - dense_1115_loss: 0.3841 - dense_1118_loss: 0.3857 - dense_1121_loss: 0.3850 - dense_1124_loss: 0.3847 - dense_1127_loss: 0.3874 - dense_1130_loss: 0.3880 - dense_1133_loss: 0.3883 - dense_1136_loss: 0.3885 - dense_1139_loss: 0.3922 - dense_1142_loss: 0.3922 - dense_1145_loss: 0.3923 - dense_1148_loss: 0.3926 - dense_1151_loss: 0.3903 - dense_1154_loss: 0.3943 - dense_1157_loss: 0.3926 - dense_1160_loss: 0.3901 - dense_1163_loss: 0.3919 - dense_1166_loss: 0.3921 - dense_1169_loss: 0.3926 - dense_1172_loss: 0.3971 - dense_1175_loss: 0.3953 - dense_1178_loss: 0.3956 - dense_1181_loss: 0.3953 - dense_1184_loss: 0.3948 - dense_1187_loss: 0.3961 - dense_1190_loss: 0.3950 - dense_1193_loss: 0.3926 - dense_1196_loss: 0.3906 - dense_1199_loss: 0.3923 - dense_1202_loss: 0.3883 - dense_1205_loss: 0.3883 - dense_1208_loss: 0.3904 - dense_1211_loss: 0.3901 - dense_1214_loss: 0.3875 - dense_1217_loss: 0.3861 - dense_1220_loss: 0.3879 - dense_1223_loss: 0.3891 - dense_1226_loss: 0.3902 - dense_1229_loss: 0.3888 - dense_1232_loss: 0.3903 - dense_1235_loss: 0.3874 - dense_1238_loss: 0.3903 - dense_1241_loss: 0.3903 - dense_1244_loss: 0.3899 - dense_1247_loss: 0.3876 - dense_1250_loss: 0.3887 - dense_1253_loss: 0.3849 - dense_1256_loss: 0.3858 - dense_1259_loss: 0.3916 - dense_1262_loss: 0.3908 - dense_1265_loss: 0.3932 - dense_1268_loss: 0.3984 - dense_1271_loss: 0.4043 - dense_1094_accuracy: 0.8237 - dense_1097_accuracy: 0.8275 - dense_1100_accuracy: 0.8279 - dense_1103_accuracy: 0.8272 - dense_1106_accuracy: 0.8276 - dense_1109_accuracy: 0.8291 - dense_1112_accuracy: 0.8287 - dense_1115_accuracy: 0.8291 - dense_1118_accuracy: 0.8288 - dense_1121_accuracy: 0.8290 - dense_1124_accuracy: 0.8284 - dense_1127_accuracy: 0.8246 - dense_1130_accuracy: 0.8261 - dense_1133_accuracy: 0.8263 - dense_1136_accuracy: 0.8275 - dense_1139_accuracy: 0.8258 - dense_1142_accuracy: 0.8263 - dense_1145_accuracy: 0.8252 - dense_1148_accuracy: 0.8240 - dense_1151_accuracy: 0.8237 - dense_1154_accuracy: 0.8222 - dense_1157_accuracy: 0.8252 - dense_1160_accuracy: 0.8278 - dense_1163_accuracy: 0.8263 - dense_1166_accuracy: 0.8248 - dense_1169_accuracy: 0.8279 - dense_1172_accuracy: 0.8225 - dense_1175_accuracy: 0.8248 - dense_1178_accuracy: 0.8248 - dense_1181_accuracy: 0.8252 - dense_1184_accuracy: 0.8260 - dense_1187_accuracy: 0.8255 - dense_1190_accuracy: 0.8266 - dense_1193_accuracy: 0.8281 - dense_1196_accuracy: 0.8288 - dense_1199_accuracy: 0.8288 - dense_1202_accuracy: 0.8320 - dense_1205_accuracy: 0.8306 - dense_1208_accuracy: 0.8293 - dense_1211_accuracy: 0.8290 - dense_1214_accuracy: 0.8293 - dense_1217_accuracy: 0.8299 - dense_1220_accuracy: 0.8266 - dense_1223_accuracy: 0.8258 - dense_1226_accuracy: 0.8243 - dense_1229_accuracy: 0.8264 - dense_1232_accuracy: 0.8261 - dense_1235_accuracy: 0.8287 - dense_1238_accuracy: 0.8296 - dense_1241_accuracy: 0.8299 - dense_1244_accuracy: 0.8303 - dense_1247_accuracy: 0.8324 - dense_1250_accuracy: 0.8330 - dense_1253_accuracy: 0.8365 - dense_1256_accuracy: 0.8371 - dense_1259_accuracy: 0.8341 - dense_1262_accuracy: 0.8342 - dense_1265_accuracy: 0.8302 - dense_1268_accuracy: 0.8290 - dense_1271_accuracy: 0.8266 - val_loss: 43.2204 - val_dense_1094_loss: 0.7701 - val_dense_1097_loss: 0.7889 - val_dense_1100_loss: 0.8098 - val_dense_1103_loss: 0.7369 - val_dense_1106_loss: 0.7498 - val_dense_1109_loss: 0.7056 - val_dense_1112_loss: 0.7347 - val_dense_1115_loss: 0.7130 - val_dense_1118_loss: 0.7197 - val_dense_1121_loss: 0.6968 - val_dense_1124_loss: 0.6804 - val_dense_1127_loss: 0.6725 - val_dense_1130_loss: 0.6640 - val_dense_1133_loss: 0.6635 - val_dense_1136_loss: 0.6986 - val_dense_1139_loss: 0.6856 - val_dense_1142_loss: 0.7032 - val_dense_1145_loss: 0.7005 - val_ ...
# Epoch 9/50
# 105/105 [==============================] - 40s 376ms/step - loss: 23.5602 - dense_1094_loss: 0.3966 - dense_1097_loss: 0.3921 - dense_1100_loss: 0.3852 - dense_1103_loss: 0.3809 - dense_1106_loss: 0.3816 - dense_1109_loss: 0.3810 - dense_1112_loss: 0.3851 - dense_1115_loss: 0.3828 - dense_1118_loss: 0.3840 - dense_1121_loss: 0.3840 - dense_1124_loss: 0.3824 - dense_1127_loss: 0.3852 - dense_1130_loss: 0.3841 - dense_1133_loss: 0.3842 - dense_1136_loss: 0.3857 - dense_1139_loss: 0.3901 - dense_1142_loss: 0.3912 - dense_1145_loss: 0.3919 - dense_1148_loss: 0.3925 - dense_1151_loss: 0.3904 - dense_1154_loss: 0.3939 - dense_1157_loss: 0.3921 - dense_1160_loss: 0.3900 - dense_1163_loss: 0.3916 - dense_1166_loss: 0.3908 - dense_1169_loss: 0.3924 - dense_1172_loss: 0.3956 - dense_1175_loss: 0.3945 - dense_1178_loss: 0.3947 - dense_1181_loss: 0.3936 - dense_1184_loss: 0.3933 - dense_1187_loss: 0.3934 - dense_1190_loss: 0.3932 - dense_1193_loss: 0.3920 - dense_1196_loss: 0.3890 - dense_1199_loss: 0.3916 - dense_1202_loss: 0.3903 - dense_1205_loss: 0.3915 - dense_1208_loss: 0.3957 - dense_1211_loss: 0.3974 - dense_1214_loss: 0.3952 - dense_1217_loss: 0.3939 - dense_1220_loss: 0.3957 - dense_1223_loss: 0.3973 - dense_1226_loss: 0.3986 - dense_1229_loss: 0.3964 - dense_1232_loss: 0.3969 - dense_1235_loss: 0.3941 - dense_1238_loss: 0.3963 - dense_1241_loss: 0.3973 - dense_1244_loss: 0.3982 - dense_1247_loss: 0.3954 - dense_1250_loss: 0.3982 - dense_1253_loss: 0.3962 - dense_1256_loss: 0.3949 - dense_1259_loss: 0.4008 - dense_1262_loss: 0.4022 - dense_1265_loss: 0.4024 - dense_1268_loss: 0.4085 - dense_1271_loss: 0.4142 - dense_1094_accuracy: 0.8248 - dense_1097_accuracy: 0.8276 - dense_1100_accuracy: 0.8306 - dense_1103_accuracy: 0.8288 - dense_1106_accuracy: 0.8297 - dense_1109_accuracy: 0.8294 - dense_1112_accuracy: 0.8255 - dense_1115_accuracy: 0.8275 - dense_1118_accuracy: 0.8266 - dense_1121_accuracy: 0.8236 - dense_1124_accuracy: 0.8263 - dense_1127_accuracy: 0.8234 - dense_1130_accuracy: 0.8248 - dense_1133_accuracy: 0.8243 - dense_1136_accuracy: 0.8252 - dense_1139_accuracy: 0.8243 - dense_1142_accuracy: 0.8218 - dense_1145_accuracy: 0.8251 - dense_1148_accuracy: 0.8231 - dense_1151_accuracy: 0.8255 - dense_1154_accuracy: 0.8230 - dense_1157_accuracy: 0.8228 - dense_1160_accuracy: 0.8249 - dense_1163_accuracy: 0.8236 - dense_1166_accuracy: 0.8227 - dense_1169_accuracy: 0.8239 - dense_1172_accuracy: 0.8234 - dense_1175_accuracy: 0.8236 - dense_1178_accuracy: 0.8249 - dense_1181_accuracy: 0.8237 - dense_1184_accuracy: 0.8248 - dense_1187_accuracy: 0.8218 - dense_1190_accuracy: 0.8230 - dense_1193_accuracy: 0.8243 - dense_1196_accuracy: 0.8275 - dense_1199_accuracy: 0.8254 - dense_1202_accuracy: 0.8242 - dense_1205_accuracy: 0.8245 - dense_1208_accuracy: 0.8213 - dense_1211_accuracy: 0.8203 - dense_1214_accuracy: 0.8233 - dense_1217_accuracy: 0.8234 - dense_1220_accuracy: 0.8236 - dense_1223_accuracy: 0.8216 - dense_1226_accuracy: 0.8206 - dense_1229_accuracy: 0.8222 - dense_1232_accuracy: 0.8222 - dense_1235_accuracy: 0.8240 - dense_1238_accuracy: 0.8261 - dense_1241_accuracy: 0.8245 - dense_1244_accuracy: 0.8258 - dense_1247_accuracy: 0.8269 - dense_1250_accuracy: 0.8234 - dense_1253_accuracy: 0.8260 - dense_1256_accuracy: 0.8267 - dense_1259_accuracy: 0.8242 - dense_1262_accuracy: 0.8227 - dense_1265_accuracy: 0.8200 - dense_1268_accuracy: 0.8197 - dense_1271_accuracy: 0.8155 - val_loss: 35.2067 - val_dense_1094_loss: 0.6336 - val_dense_1097_loss: 0.6151 - val_dense_1100_loss: 0.6010 - val_dense_1103_loss: 0.6293 - val_dense_1106_loss: 0.6423 - val_dense_1109_loss: 0.6707 - val_dense_1112_loss: 0.6716 - val_dense_1115_loss: 0.6603 - val_dense_1118_loss: 0.6506 - val_dense_1121_loss: 0.6492 - val_dense_1124_loss: 0.6374 - val_dense_1127_loss: 0.6211 - val_dense_1130_loss: 0.6169 - val_dense_1133_loss: 0.6125 - val_dense_1136_loss: 0.6094 - val_dense_1139_loss: 0.5982 - val_dense_1142_loss: 0.6160 - val_dense_1145_loss: 0.6234 - val_ ...
# Epoch 10/50
# 105/105 [==============================] - 40s 377ms/step - loss: 23.0789 - dense_1094_loss: 0.3918 - dense_1097_loss: 0.3865 - dense_1100_loss: 0.3790 - dense_1103_loss: 0.3765 - dense_1106_loss: 0.3793 - dense_1109_loss: 0.3775 - dense_1112_loss: 0.3791 - dense_1115_loss: 0.3763 - dense_1118_loss: 0.3775 - dense_1121_loss: 0.3791 - dense_1124_loss: 0.3777 - dense_1127_loss: 0.3803 - dense_1130_loss: 0.3789 - dense_1133_loss: 0.3784 - dense_1136_loss: 0.3797 - dense_1139_loss: 0.3855 - dense_1142_loss: 0.3865 - dense_1145_loss: 0.3859 - dense_1148_loss: 0.3880 - dense_1151_loss: 0.3847 - dense_1154_loss: 0.3881 - dense_1157_loss: 0.3858 - dense_1160_loss: 0.3840 - dense_1163_loss: 0.3864 - dense_1166_loss: 0.3860 - dense_1169_loss: 0.3852 - dense_1172_loss: 0.3872 - dense_1175_loss: 0.3861 - dense_1178_loss: 0.3862 - dense_1181_loss: 0.3844 - dense_1184_loss: 0.3842 - dense_1187_loss: 0.3850 - dense_1190_loss: 0.3855 - dense_1193_loss: 0.3833 - dense_1196_loss: 0.3833 - dense_1199_loss: 0.3861 - dense_1202_loss: 0.3826 - dense_1205_loss: 0.3837 - dense_1208_loss: 0.3852 - dense_1211_loss: 0.3876 - dense_1214_loss: 0.3864 - dense_1217_loss: 0.3843 - dense_1220_loss: 0.3873 - dense_1223_loss: 0.3874 - dense_1226_loss: 0.3869 - dense_1229_loss: 0.3844 - dense_1232_loss: 0.3850 - dense_1235_loss: 0.3817 - dense_1238_loss: 0.3836 - dense_1241_loss: 0.3847 - dense_1244_loss: 0.3857 - dense_1247_loss: 0.3845 - dense_1250_loss: 0.3853 - dense_1253_loss: 0.3828 - dense_1256_loss: 0.3854 - dense_1259_loss: 0.3911 - dense_1262_loss: 0.3902 - dense_1265_loss: 0.3908 - dense_1268_loss: 0.3955 - dense_1271_loss: 0.4016 - dense_1094_accuracy: 0.8267 - dense_1097_accuracy: 0.8309 - dense_1100_accuracy: 0.8342 - dense_1103_accuracy: 0.8341 - dense_1106_accuracy: 0.8332 - dense_1109_accuracy: 0.8357 - dense_1112_accuracy: 0.8342 - dense_1115_accuracy: 0.8362 - dense_1118_accuracy: 0.8339 - dense_1121_accuracy: 0.8311 - dense_1124_accuracy: 0.8323 - dense_1127_accuracy: 0.8306 - dense_1130_accuracy: 0.8305 - dense_1133_accuracy: 0.8320 - dense_1136_accuracy: 0.8317 - dense_1139_accuracy: 0.8281 - dense_1142_accuracy: 0.8264 - dense_1145_accuracy: 0.8281 - dense_1148_accuracy: 0.8273 - dense_1151_accuracy: 0.8294 - dense_1154_accuracy: 0.8281 - dense_1157_accuracy: 0.8246 - dense_1160_accuracy: 0.8264 - dense_1163_accuracy: 0.8246 - dense_1166_accuracy: 0.8246 - dense_1169_accuracy: 0.8278 - dense_1172_accuracy: 0.8273 - dense_1175_accuracy: 0.8276 - dense_1178_accuracy: 0.8270 - dense_1181_accuracy: 0.8287 - dense_1184_accuracy: 0.8288 - dense_1187_accuracy: 0.8266 - dense_1190_accuracy: 0.8252 - dense_1193_accuracy: 0.8266 - dense_1196_accuracy: 0.8260 - dense_1199_accuracy: 0.8272 - dense_1202_accuracy: 0.8272 - dense_1205_accuracy: 0.8284 - dense_1208_accuracy: 0.8281 - dense_1211_accuracy: 0.8260 - dense_1214_accuracy: 0.8275 - dense_1217_accuracy: 0.8287 - dense_1220_accuracy: 0.8261 - dense_1223_accuracy: 0.8267 - dense_1226_accuracy: 0.8279 - dense_1229_accuracy: 0.8284 - dense_1232_accuracy: 0.8275 - dense_1235_accuracy: 0.8299 - dense_1238_accuracy: 0.8314 - dense_1241_accuracy: 0.8290 - dense_1244_accuracy: 0.8297 - dense_1247_accuracy: 0.8312 - dense_1250_accuracy: 0.8300 - dense_1253_accuracy: 0.8326 - dense_1256_accuracy: 0.8333 - dense_1259_accuracy: 0.8299 - dense_1262_accuracy: 0.8303 - dense_1265_accuracy: 0.8284 - dense_1268_accuracy: 0.8281 - dense_1271_accuracy: 0.8243 - val_loss: 37.4705 - val_dense_1094_loss: 0.6806 - val_dense_1097_loss: 0.6536 - val_dense_1100_loss: 0.6582 - val_dense_1103_loss: 0.6846 - val_dense_1106_loss: 0.6545 - val_dense_1109_loss: 0.6763 - val_dense_1112_loss: 0.6615 - val_dense_1115_loss: 0.6662 - val_dense_1118_loss: 0.6541 - val_dense_1121_loss: 0.6308 - val_dense_1124_loss: 0.6188 - val_dense_1127_loss: 0.5959 - val_dense_1130_loss: 0.5929 - val_dense_1133_loss: 0.6014 - val_dense_1136_loss: 0.6031 - val_dense_1139_loss: 0.6085 - val_dense_1142_loss: 0.6093 - val_dense_1145_loss: 0.6034 - val_ ...
# Epoch 11/50
# 105/105 [==============================] - 40s 377ms/step - loss: 22.4844 - dense_1094_loss: 0.3845 - dense_1097_loss: 0.3782 - dense_1100_loss: 0.3703 - dense_1103_loss: 0.3672 - dense_1106_loss: 0.3681 - dense_1109_loss: 0.3665 - dense_1112_loss: 0.3698 - dense_1115_loss: 0.3673 - dense_1118_loss: 0.3676 - dense_1121_loss: 0.3686 - dense_1124_loss: 0.3685 - dense_1127_loss: 0.3706 - dense_1130_loss: 0.3693 - dense_1133_loss: 0.3695 - dense_1136_loss: 0.3695 - dense_1139_loss: 0.3743 - dense_1142_loss: 0.3743 - dense_1145_loss: 0.3743 - dense_1148_loss: 0.3742 - dense_1151_loss: 0.3725 - dense_1154_loss: 0.3771 - dense_1157_loss: 0.3761 - dense_1160_loss: 0.3733 - dense_1163_loss: 0.3759 - dense_1166_loss: 0.3764 - dense_1169_loss: 0.3753 - dense_1172_loss: 0.3781 - dense_1175_loss: 0.3770 - dense_1178_loss: 0.3762 - dense_1181_loss: 0.3775 - dense_1184_loss: 0.3755 - dense_1187_loss: 0.3773 - dense_1190_loss: 0.3765 - dense_1193_loss: 0.3738 - dense_1196_loss: 0.3732 - dense_1199_loss: 0.3753 - dense_1202_loss: 0.3731 - dense_1205_loss: 0.3732 - dense_1208_loss: 0.3759 - dense_1211_loss: 0.3768 - dense_1214_loss: 0.3761 - dense_1217_loss: 0.3734 - dense_1220_loss: 0.3779 - dense_1223_loss: 0.3777 - dense_1226_loss: 0.3773 - dense_1229_loss: 0.3759 - dense_1232_loss: 0.3766 - dense_1235_loss: 0.3737 - dense_1238_loss: 0.3763 - dense_1241_loss: 0.3761 - dense_1244_loss: 0.3763 - dense_1247_loss: 0.3733 - dense_1250_loss: 0.3752 - dense_1253_loss: 0.3717 - dense_1256_loss: 0.3738 - dense_1259_loss: 0.3796 - dense_1262_loss: 0.3785 - dense_1265_loss: 0.3796 - dense_1268_loss: 0.3851 - dense_1271_loss: 0.3919 - dense_1094_accuracy: 0.8318 - dense_1097_accuracy: 0.8362 - dense_1100_accuracy: 0.8392 - dense_1103_accuracy: 0.8386 - dense_1106_accuracy: 0.8402 - dense_1109_accuracy: 0.8411 - dense_1112_accuracy: 0.8387 - dense_1115_accuracy: 0.8398 - dense_1118_accuracy: 0.8392 - dense_1121_accuracy: 0.8357 - dense_1124_accuracy: 0.8365 - dense_1127_accuracy: 0.8348 - dense_1130_accuracy: 0.8360 - dense_1133_accuracy: 0.8359 - dense_1136_accuracy: 0.8375 - dense_1139_accuracy: 0.8342 - dense_1142_accuracy: 0.8362 - dense_1145_accuracy: 0.8351 - dense_1148_accuracy: 0.8332 - dense_1151_accuracy: 0.8366 - dense_1154_accuracy: 0.8348 - dense_1157_accuracy: 0.8356 - dense_1160_accuracy: 0.8356 - dense_1163_accuracy: 0.8363 - dense_1166_accuracy: 0.8341 - dense_1169_accuracy: 0.8348 - dense_1172_accuracy: 0.8335 - dense_1175_accuracy: 0.8348 - dense_1178_accuracy: 0.8347 - dense_1181_accuracy: 0.8335 - dense_1184_accuracy: 0.8347 - dense_1187_accuracy: 0.8338 - dense_1190_accuracy: 0.8357 - dense_1193_accuracy: 0.8368 - dense_1196_accuracy: 0.8369 - dense_1199_accuracy: 0.8389 - dense_1202_accuracy: 0.8390 - dense_1205_accuracy: 0.8366 - dense_1208_accuracy: 0.8344 - dense_1211_accuracy: 0.8342 - dense_1214_accuracy: 0.8368 - dense_1217_accuracy: 0.8374 - dense_1220_accuracy: 0.8335 - dense_1223_accuracy: 0.8321 - dense_1226_accuracy: 0.8323 - dense_1229_accuracy: 0.8348 - dense_1232_accuracy: 0.8329 - dense_1235_accuracy: 0.8375 - dense_1238_accuracy: 0.8365 - dense_1241_accuracy: 0.8384 - dense_1244_accuracy: 0.8378 - dense_1247_accuracy: 0.8366 - dense_1250_accuracy: 0.8374 - dense_1253_accuracy: 0.8375 - dense_1256_accuracy: 0.8368 - dense_1259_accuracy: 0.8341 - dense_1262_accuracy: 0.8357 - dense_1265_accuracy: 0.8318 - dense_1268_accuracy: 0.8297 - dense_1271_accuracy: 0.8263 - val_loss: 35.5650 - val_dense_1094_loss: 0.6277 - val_dense_1097_loss: 0.6108 - val_dense_1100_loss: 0.6297 - val_dense_1103_loss: 0.6321 - val_dense_1106_loss: 0.6433 - val_dense_1109_loss: 0.6651 - val_dense_1112_loss: 0.6937 - val_dense_1115_loss: 0.6702 - val_dense_1118_loss: 0.6715 - val_dense_1121_loss: 0.6660 - val_dense_1124_loss: 0.6460 - val_dense_1127_loss: 0.6165 - val_dense_1130_loss: 0.6362 - val_dense_1133_loss: 0.5869 - val_dense_1136_loss: 0.5905 - val_dense_1139_loss: 0.5837 - val_dense_1142_loss: 0.6084 - val_dense_1145_loss: 0.6046 - val_ ...
# Epoch 12/50
# 105/105 [==============================] - 41s 394ms/step - loss: 23.3862 - dense_1094_loss: 0.3969 - dense_1097_loss: 0.3939 - dense_1100_loss: 0.3834 - dense_1103_loss: 0.3824 - dense_1106_loss: 0.3844 - dense_1109_loss: 0.3850 - dense_1112_loss: 0.3860 - dense_1115_loss: 0.3826 - dense_1118_loss: 0.3850 - dense_1121_loss: 0.3850 - dense_1124_loss: 0.3839 - dense_1127_loss: 0.3840 - dense_1130_loss: 0.3839 - dense_1133_loss: 0.3829 - dense_1136_loss: 0.3836 - dense_1139_loss: 0.3899 - dense_1142_loss: 0.3913 - dense_1145_loss: 0.3938 - dense_1148_loss: 0.3941 - dense_1151_loss: 0.3922 - dense_1154_loss: 0.3945 - dense_1157_loss: 0.3940 - dense_1160_loss: 0.3909 - dense_1163_loss: 0.3932 - dense_1166_loss: 0.3935 - dense_1169_loss: 0.3928 - dense_1172_loss: 0.3955 - dense_1175_loss: 0.3947 - dense_1178_loss: 0.3953 - dense_1181_loss: 0.3917 - dense_1184_loss: 0.3907 - dense_1187_loss: 0.3894 - dense_1190_loss: 0.3885 - dense_1193_loss: 0.3862 - dense_1196_loss: 0.3864 - dense_1199_loss: 0.3902 - dense_1202_loss: 0.3847 - dense_1205_loss: 0.3865 - dense_1208_loss: 0.3877 - dense_1211_loss: 0.3899 - dense_1214_loss: 0.3894 - dense_1217_loss: 0.3871 - dense_1220_loss: 0.3885 - dense_1223_loss: 0.3906 - dense_1226_loss: 0.3915 - dense_1229_loss: 0.3892 - dense_1232_loss: 0.3900 - dense_1235_loss: 0.3877 - dense_1238_loss: 0.3900 - dense_1241_loss: 0.3899 - dense_1244_loss: 0.3919 - dense_1247_loss: 0.3880 - dense_1250_loss: 0.3886 - dense_1253_loss: 0.3858 - dense_1256_loss: 0.3879 - dense_1259_loss: 0.3944 - dense_1262_loss: 0.3944 - dense_1265_loss: 0.3960 - dense_1268_loss: 0.3997 - dense_1271_loss: 0.4053 - dense_1094_accuracy: 0.8248 - dense_1097_accuracy: 0.8251 - dense_1100_accuracy: 0.8300 - dense_1103_accuracy: 0.8287 - dense_1106_accuracy: 0.8270 - dense_1109_accuracy: 0.8311 - dense_1112_accuracy: 0.8291 - dense_1115_accuracy: 0.8308 - dense_1118_accuracy: 0.8300 - dense_1121_accuracy: 0.8278 - dense_1124_accuracy: 0.8272 - dense_1127_accuracy: 0.8281 - dense_1130_accuracy: 0.8276 - dense_1133_accuracy: 0.8299 - dense_1136_accuracy: 0.8266 - dense_1139_accuracy: 0.8231 - dense_1142_accuracy: 0.8246 - dense_1145_accuracy: 0.8228 - dense_1148_accuracy: 0.8210 - dense_1151_accuracy: 0.8234 - dense_1154_accuracy: 0.8222 - dense_1157_accuracy: 0.8198 - dense_1160_accuracy: 0.8225 - dense_1163_accuracy: 0.8209 - dense_1166_accuracy: 0.8221 - dense_1169_accuracy: 0.8198 - dense_1172_accuracy: 0.8194 - dense_1175_accuracy: 0.8224 - dense_1178_accuracy: 0.8207 - dense_1181_accuracy: 0.8254 - dense_1184_accuracy: 0.8260 - dense_1187_accuracy: 0.8264 - dense_1190_accuracy: 0.8279 - dense_1193_accuracy: 0.8294 - dense_1196_accuracy: 0.8315 - dense_1199_accuracy: 0.8273 - dense_1202_accuracy: 0.8317 - dense_1205_accuracy: 0.8287 - dense_1208_accuracy: 0.8287 - dense_1211_accuracy: 0.8275 - dense_1214_accuracy: 0.8264 - dense_1217_accuracy: 0.8291 - dense_1220_accuracy: 0.8240 - dense_1223_accuracy: 0.8240 - dense_1226_accuracy: 0.8218 - dense_1229_accuracy: 0.8251 - dense_1232_accuracy: 0.8248 - dense_1235_accuracy: 0.8255 - dense_1238_accuracy: 0.8254 - dense_1241_accuracy: 0.8257 - dense_1244_accuracy: 0.8234 - dense_1247_accuracy: 0.8303 - dense_1250_accuracy: 0.8279 - dense_1253_accuracy: 0.8300 - dense_1256_accuracy: 0.8311 - dense_1259_accuracy: 0.8287 - dense_1262_accuracy: 0.8276 - dense_1265_accuracy: 0.8270 - dense_1268_accuracy: 0.8254 - dense_1271_accuracy: 0.8222 - val_loss: 39.9142 - val_dense_1094_loss: 0.7260 - val_dense_1097_loss: 0.7220 - val_dense_1100_loss: 0.7353 - val_dense_1103_loss: 0.7548 - val_dense_1106_loss: 0.7446 - val_dense_1109_loss: 0.7320 - val_dense_1112_loss: 0.7319 - val_dense_1115_loss: 0.7251 - val_dense_1118_loss: 0.7303 - val_dense_1121_loss: 0.7055 - val_dense_1124_loss: 0.6922 - val_dense_1127_loss: 0.6645 - val_dense_1130_loss: 0.6821 - val_dense_1133_loss: 0.6801 - val_dense_1136_loss: 0.6791 - val_dense_1139_loss: 0.6601 - val_dense_1142_loss: 0.6727 - val_dense_1145_loss: 0.6422 - val_ ...
# Epoch 13/50
# 105/105 [==============================] - 39s 371ms/step - loss: 23.3605 - dense_1094_loss: 0.4018 - dense_1097_loss: 0.3990 - dense_1100_loss: 0.3871 - dense_1103_loss: 0.3856 - dense_1106_loss: 0.3841 - dense_1109_loss: 0.3810 - dense_1112_loss: 0.3819 - dense_1115_loss: 0.3791 - dense_1118_loss: 0.3809 - dense_1121_loss: 0.3817 - dense_1124_loss: 0.3800 - dense_1127_loss: 0.3818 - dense_1130_loss: 0.3816 - dense_1133_loss: 0.3819 - dense_1136_loss: 0.3818 - dense_1139_loss: 0.3874 - dense_1142_loss: 0.3866 - dense_1145_loss: 0.3877 - dense_1148_loss: 0.3874 - dense_1151_loss: 0.3846 - dense_1154_loss: 0.3881 - dense_1157_loss: 0.3873 - dense_1160_loss: 0.3849 - dense_1163_loss: 0.3873 - dense_1166_loss: 0.3873 - dense_1169_loss: 0.3881 - dense_1172_loss: 0.3903 - dense_1175_loss: 0.3899 - dense_1178_loss: 0.3901 - dense_1181_loss: 0.3896 - dense_1184_loss: 0.3884 - dense_1187_loss: 0.3907 - dense_1190_loss: 0.3898 - dense_1193_loss: 0.3888 - dense_1196_loss: 0.3887 - dense_1199_loss: 0.3907 - dense_1202_loss: 0.3887 - dense_1205_loss: 0.3900 - dense_1208_loss: 0.3914 - dense_1211_loss: 0.3933 - dense_1214_loss: 0.3922 - dense_1217_loss: 0.3902 - dense_1220_loss: 0.3918 - dense_1223_loss: 0.3918 - dense_1226_loss: 0.3935 - dense_1229_loss: 0.3917 - dense_1232_loss: 0.3915 - dense_1235_loss: 0.3885 - dense_1238_loss: 0.3908 - dense_1241_loss: 0.3918 - dense_1244_loss: 0.3943 - dense_1247_loss: 0.3933 - dense_1250_loss: 0.3931 - dense_1253_loss: 0.3901 - dense_1256_loss: 0.3898 - dense_1259_loss: 0.3966 - dense_1262_loss: 0.3963 - dense_1265_loss: 0.3979 - dense_1268_loss: 0.4017 - dense_1271_loss: 0.4070 - dense_1094_accuracy: 0.8188 - dense_1097_accuracy: 0.8224 - dense_1100_accuracy: 0.8240 - dense_1103_accuracy: 0.8246 - dense_1106_accuracy: 0.8260 - dense_1109_accuracy: 0.8309 - dense_1112_accuracy: 0.8269 - dense_1115_accuracy: 0.8278 - dense_1118_accuracy: 0.8285 - dense_1121_accuracy: 0.8278 - dense_1124_accuracy: 0.8287 - dense_1127_accuracy: 0.8257 - dense_1130_accuracy: 0.8288 - dense_1133_accuracy: 0.8276 - dense_1136_accuracy: 0.8281 - dense_1139_accuracy: 0.8249 - dense_1142_accuracy: 0.8279 - dense_1145_accuracy: 0.8255 - dense_1148_accuracy: 0.8219 - dense_1151_accuracy: 0.8234 - dense_1154_accuracy: 0.8218 - dense_1157_accuracy: 0.8200 - dense_1160_accuracy: 0.8219 - dense_1163_accuracy: 0.8216 - dense_1166_accuracy: 0.8204 - dense_1169_accuracy: 0.8222 - dense_1172_accuracy: 0.8225 - dense_1175_accuracy: 0.8221 - dense_1178_accuracy: 0.8224 - dense_1181_accuracy: 0.8224 - dense_1184_accuracy: 0.8225 - dense_1187_accuracy: 0.8209 - dense_1190_accuracy: 0.8219 - dense_1193_accuracy: 0.8249 - dense_1196_accuracy: 0.8228 - dense_1199_accuracy: 0.8236 - dense_1202_accuracy: 0.8228 - dense_1205_accuracy: 0.8204 - dense_1208_accuracy: 0.8195 - dense_1211_accuracy: 0.8207 - dense_1214_accuracy: 0.8242 - dense_1217_accuracy: 0.8255 - dense_1220_accuracy: 0.8263 - dense_1223_accuracy: 0.8263 - dense_1226_accuracy: 0.8243 - dense_1229_accuracy: 0.8261 - dense_1232_accuracy: 0.8261 - dense_1235_accuracy: 0.8306 - dense_1238_accuracy: 0.8312 - dense_1241_accuracy: 0.8291 - dense_1244_accuracy: 0.8296 - dense_1247_accuracy: 0.8294 - dense_1250_accuracy: 0.8296 - dense_1253_accuracy: 0.8299 - dense_1256_accuracy: 0.8332 - dense_1259_accuracy: 0.8281 - dense_1262_accuracy: 0.8261 - dense_1265_accuracy: 0.8230 - dense_1268_accuracy: 0.8233 - dense_1271_accuracy: 0.8180 - val_loss: 33.7332 - val_dense_1094_loss: 0.5895 - val_dense_1097_loss: 0.6158 - val_dense_1100_loss: 0.6220 - val_dense_1103_loss: 0.6034 - val_dense_1106_loss: 0.5795 - val_dense_1109_loss: 0.5584 - val_dense_1112_loss: 0.5601 - val_dense_1115_loss: 0.5622 - val_dense_1118_loss: 0.5661 - val_dense_1121_loss: 0.5586 - val_dense_1124_loss: 0.5574 - val_dense_1127_loss: 0.5333 - val_dense_1130_loss: 0.5364 - val_dense_1133_loss: 0.5385 - val_dense_1136_loss: 0.5447 - val_dense_1139_loss: 0.5645 - val_dense_1142_loss: 0.5623 - val_dense_1145_loss: 0.5484 - val_ ...
# Epoch 14/50
# 105/105 [==============================] - 40s 380ms/step - loss: 21.9820 - dense_1094_loss: 0.3797 - dense_1097_loss: 0.3729 - dense_1100_loss: 0.3640 - dense_1103_loss: 0.3627 - dense_1106_loss: 0.3627 - dense_1109_loss: 0.3617 - dense_1112_loss: 0.3635 - dense_1115_loss: 0.3593 - dense_1118_loss: 0.3610 - dense_1121_loss: 0.3619 - dense_1124_loss: 0.3602 - dense_1127_loss: 0.3627 - dense_1130_loss: 0.3611 - dense_1133_loss: 0.3599 - dense_1136_loss: 0.3607 - dense_1139_loss: 0.3644 - dense_1142_loss: 0.3658 - dense_1145_loss: 0.3667 - dense_1148_loss: 0.3673 - dense_1151_loss: 0.3653 - dense_1154_loss: 0.3690 - dense_1157_loss: 0.3667 - dense_1160_loss: 0.3642 - dense_1163_loss: 0.3654 - dense_1166_loss: 0.3648 - dense_1169_loss: 0.3634 - dense_1172_loss: 0.3666 - dense_1175_loss: 0.3659 - dense_1178_loss: 0.3656 - dense_1181_loss: 0.3653 - dense_1184_loss: 0.3652 - dense_1187_loss: 0.3677 - dense_1190_loss: 0.3657 - dense_1193_loss: 0.3645 - dense_1196_loss: 0.3649 - dense_1199_loss: 0.3684 - dense_1202_loss: 0.3626 - dense_1205_loss: 0.3640 - dense_1208_loss: 0.3655 - dense_1211_loss: 0.3672 - dense_1214_loss: 0.3660 - dense_1217_loss: 0.3651 - dense_1220_loss: 0.3670 - dense_1223_loss: 0.3693 - dense_1226_loss: 0.3706 - dense_1229_loss: 0.3679 - dense_1232_loss: 0.3681 - dense_1235_loss: 0.3653 - dense_1238_loss: 0.3677 - dense_1241_loss: 0.3684 - dense_1244_loss: 0.3698 - dense_1247_loss: 0.3683 - dense_1250_loss: 0.3674 - dense_1253_loss: 0.3639 - dense_1256_loss: 0.3642 - dense_1259_loss: 0.3708 - dense_1262_loss: 0.3706 - dense_1265_loss: 0.3724 - dense_1268_loss: 0.3784 - dense_1271_loss: 0.3846 - dense_1094_accuracy: 0.8339 - dense_1097_accuracy: 0.8339 - dense_1100_accuracy: 0.8386 - dense_1103_accuracy: 0.8389 - dense_1106_accuracy: 0.8363 - dense_1109_accuracy: 0.8390 - dense_1112_accuracy: 0.8359 - dense_1115_accuracy: 0.8363 - dense_1118_accuracy: 0.8372 - dense_1121_accuracy: 0.8369 - dense_1124_accuracy: 0.8387 - dense_1127_accuracy: 0.8386 - dense_1130_accuracy: 0.8396 - dense_1133_accuracy: 0.8395 - dense_1136_accuracy: 0.8396 - dense_1139_accuracy: 0.8371 - dense_1142_accuracy: 0.8375 - dense_1145_accuracy: 0.8389 - dense_1148_accuracy: 0.8353 - dense_1151_accuracy: 0.8366 - dense_1154_accuracy: 0.8357 - dense_1157_accuracy: 0.8348 - dense_1160_accuracy: 0.8353 - dense_1163_accuracy: 0.8351 - dense_1166_accuracy: 0.8371 - dense_1169_accuracy: 0.8413 - dense_1172_accuracy: 0.8368 - dense_1175_accuracy: 0.8398 - dense_1178_accuracy: 0.8390 - dense_1181_accuracy: 0.8396 - dense_1184_accuracy: 0.8390 - dense_1187_accuracy: 0.8389 - dense_1190_accuracy: 0.8392 - dense_1193_accuracy: 0.8404 - dense_1196_accuracy: 0.8423 - dense_1199_accuracy: 0.8432 - dense_1202_accuracy: 0.8428 - dense_1205_accuracy: 0.8425 - dense_1208_accuracy: 0.8381 - dense_1211_accuracy: 0.8374 - dense_1214_accuracy: 0.8396 - dense_1217_accuracy: 0.8405 - dense_1220_accuracy: 0.8410 - dense_1223_accuracy: 0.8386 - dense_1226_accuracy: 0.8368 - dense_1229_accuracy: 0.8390 - dense_1232_accuracy: 0.8408 - dense_1235_accuracy: 0.8399 - dense_1238_accuracy: 0.8417 - dense_1241_accuracy: 0.8392 - dense_1244_accuracy: 0.8375 - dense_1247_accuracy: 0.8393 - dense_1250_accuracy: 0.8390 - dense_1253_accuracy: 0.8411 - dense_1256_accuracy: 0.8434 - dense_1259_accuracy: 0.8416 - dense_1262_accuracy: 0.8405 - dense_1265_accuracy: 0.8392 - dense_1268_accuracy: 0.8374 - dense_1271_accuracy: 0.8324 - val_loss: 32.2061 - val_dense_1094_loss: 0.5626 - val_dense_1097_loss: 0.5780 - val_dense_1100_loss: 0.5987 - val_dense_1103_loss: 0.5972 - val_dense_1106_loss: 0.5908 - val_dense_1109_loss: 0.5852 - val_dense_1112_loss: 0.5932 - val_dense_1115_loss: 0.6001 - val_dense_1118_loss: 0.6035 - val_dense_1121_loss: 0.5767 - val_dense_1124_loss: 0.5724 - val_dense_1127_loss: 0.5582 - val_dense_1130_loss: 0.5681 - val_dense_1133_loss: 0.5536 - val_dense_1136_loss: 0.5589 - val_dense_1139_loss: 0.5721 - val_dense_1142_loss: 0.5644 - val_dense_1145_loss: 0.5545 - val_ ...
# The average accuracy on validation dataset is: 0.7195
# 13/13 [==============================] - 30s 96ms/step
# 13/13 [==============================] - 1s 96ms/step
# Accuracy on test dataset is: 0.4378
# F1-score on test dataset is: 0.368
# FA is: 1.2143
# MISS is: 0.4338
# DER is: 1.6481
# 25/25 [==============================] - 2s 97ms/step
